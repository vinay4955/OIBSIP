# %% [markdown]
# **SALES PREDICTION**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/Advertising.csv")
df
# Out:
#      Sr.no     TV  Radio  Newspaper  Sales
# 0        1  230.1   37.8       69.2   22.1
# 1        2   44.5   39.3       45.1   10.4
# 2        3   17.2   45.9       69.3    9.3
# 3        4  151.5   41.3       58.5   18.5
# 4        5  180.8   10.8       58.4   12.9
# ..     ...    ...    ...        ...    ...
# 195    196   38.2    3.7       13.8    7.6
# 196    197   94.2    4.9        8.1    9.7
# 197    198  177.0    9.3        6.4   12.8
# 198    199  283.6   42.0       66.2   25.5
# 199    200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3087353906951233135 = autoviz.get_registered_df('df_3087353906951233135')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sr.no      200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.head(10)
# Out:
#    Sr.no     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# 5      6    8.7   48.9       75.0    7.2
# 6      7   57.5   32.8       23.5   11.8
# 7      8  120.2   19.6       11.6   13.2
# 8      9    8.6    2.1        1.0    4.8
# 9     10  199.8    2.6       21.2   10.6
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4593986773269988571 = autoviz.get_registered_df('df_4593986773269988571')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
# ...

# %%
df.tail(10)
# Out:
#      Sr.no     TV  Radio  Newspaper  Sales
# 190    191   39.5   41.1        5.8   10.8
# 191    192   75.5   10.8        6.0    9.9
# 192    193   17.2    4.1       31.6    5.9
# 193    194  166.8   42.0        3.6   19.6
# 194    195  149.7   35.6        6.0   17.3
# 195    196   38.2    3.7       13.8    7.6
# 196    197   94.2    4.9        8.1    9.7
# 197    198  177.0    9.3        6.4   12.8
# 198    199  283.6   42.0       66.2   25.5
# 199    200  232.1    8.6        8.7   13.4
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1950111934395026753 = autoviz.get_registered_df('df_1950111934395026753')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
# ...

# %%
df.describe()
# Out:
#             Sr.no          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7574819810830240292 = autoviz.get_registered_df('df_7574819810830240292')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
# ...

# %%
print("Dimensions: ",df.shape)
print("Size of advertisement Dataset: ",df.size)
print("Names of columns in sales prediction: \n",df.columns)
# Out:
# Dimensions:  (200, 5)
# Size of advertisement Dataset:  1000
# Names of columns in sales prediction:
#  Index(['Sr.no', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isna().sum()
# Out:
# Sr.no        0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# Sr.no      200.0  100.5000  57.879185  1.0  50.750  100.50  150.250  200.0
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7509197444409918978 = autoviz.get_registered_df('df_7509197444409918978')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
# ...

# %%
df.isnull().sum()
# Out:
# Sr.no        0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
plt.figure(figsize=(9,9))
sns.distplot(df['Sales'])
plt.show()
# Out:
# <ipython-input-11-7840a9d2cda7>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'])

# %%
plt.figure(figsize=(7,7))
sns.distplot(df['TV'])
plt.show()
# Out:
# <ipython-input-12-69c32f879d31>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TV'])

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Radio'])
plt.show()
# Out:
# <ipython-input-13-229c887eea9d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Radio'])

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Newspaper'])
plt.show()
# Out:
# <ipython-input-14-c2b109876b82>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])

# %%
df.isnull().sum()
# Out:
# Sr.no        0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    200
# dtype: int64

# %%
sns.pairplot(df)

# %%
corr=df.corr()
df.corr().T
# Out:
#               Sr.no        TV     Radio  Newspaper     Sales
# Sr.no      1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV         0.017715  1.000000  0.054809   0.056648  0.782224
# Radio     -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales     -0.051616  0.782224  0.576223   0.228299  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5349809560552387069 = autoviz.get_registered_df('df_5349809560552387069')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
# Out:
# <Axes: >

# %%
df1 = df.drop(['Sr.no'], axis=1, inplace=True)
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3087353906951233135 = autoviz.get_registered_df('df_3087353906951233135')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
# ...

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X =np.array(df.drop(['Sales'], 1))
y =np.array(df['Sales'])
# Out:
# <ipython-input-22-0f5fb5e6cf60>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X =np.array(df.drop(['Sales'], 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y,train_size=0.8,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = regressor1.predict(X_test)
y_prediction
# Out:
# array([10.05739563,  7.4522807 ,  7.0197076 , 24.08029725, 12.01786259,
#         6.53793858, 12.78286918, 15.10974587, 10.76974013, 16.34357951,
#        22.88297477,  9.12924467, 10.46455672, 15.48743552, 11.58555633,
#        12.17296914, 18.76551502, 10.78318566, 15.90515992, 17.30651279,
#        24.06692057,  9.59834224, 15.13512211, 12.38591525,  5.71360885,
#        15.24749314, 12.29402334, 20.9421167 , 13.40991558,  9.04348832,
#        12.89239415, 21.40272028, 18.13802209, 21.17320803,  6.56974433,
#         6.14114206,  7.89018394, 13.01541434, 14.68953791,  6.18835143])

# %%
coef = regressor1.coef_
coef
# Out:
# array([ 0.04458402,  0.19649703, -0.00278146])

# %%
intercept = regressor1.intercept_
intercept
# Out:
# 2.994893030495332

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_prediction)
# Out:
# 0.8601145185017868

# %%
flatten=pd.DataFrame(data={'Forecasted Sales': y_prediction.flatten()})
flatten
# Out:
#     Forecasted Sales
# 0          10.057396
# 1           7.452281
# 2           7.019708
# 3          24.080297
# 4          12.017863
# 5           6.537939
# 6          12.782869
# 7          15.109746
# 8          10.769740
# 9          16.343580
# 10         22.882975
# 11          9.129245
# 12         10.464557
# 13         15.487436
# 14         11.585556
# 15         12.172969
# 16         18.765515
# 17         10.783186
# 18         15.905160
# 19         17.306513
# 20         24.066921
# 21          9.598342
# 22         15.135122
# 23         12.385915
# 24          5.713609
# 25         15.247493
# 26         12.294023
# 27         20.942117
# 28         13.409916
# 29          9.043488
# 30         12.892394
# 31         21.402720
# 32         18.138022
# 33         21.173208
# 34          6.569744
# 35          6.141142
# 36          7.890184
# 37         13.015414
# 38         14.689538
# 39          6.188351
# <h4 class="colab-quickchart-section-title">Values</h4>
# ...

# %%
plt.figure(figsize=(8,8))
sns.distplot(flatten['Forecasted Sales'])
plt.show()
# Out:
# <ipython-input-30-428c6d508acf>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(flatten['Forecasted Sales'])
